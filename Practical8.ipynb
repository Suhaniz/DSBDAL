# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(0,10)
y=np.arange(0,10)

# %%
x = np.arange(1, 12)
y = 3 * x + 5
plt.plot(x, y, label='y = 3x + 5', color='b')

plt.xlabel('x') 
plt.ylabel('y')  

plt.title('Plot of y = 3x + 5')

plt.grid(True)
plt.show()

# %%
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y, label='y = sin(x)', color='r')

plt.xlabel('x')  
plt.ylabel('y') 

plt.title('Plot of y = sin(x)')
plt.grid(True)

# %%
x = np.arange(0, 5 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))  # 2 rows, 1 column

ax1.plot(x, y_sin, label='y = sin(x)', color='r')
ax1.set_title('Plot of y = sin(x)')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True)
ax1.legend()

ax2.plot(x, y_cos, label='y = cos(x)', color='b')
ax2.set_title('Plot of y = cos(x)')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)

# %%
plt.subplot(1, 2, 1) 
plt.plot(x, y)         
plt.title("x vs y")  
plt.xlabel("x")       
plt.ylabel("y") 

plt.tight_layout()
plt.show()

# %%
plt.plot(x,y)

# %%
x=np.arange(0,10)
y_sin = np.sin(x)
y_cos = np.cos(x)

# %%
plt.subplot(2,2,1)
plt.title("Sine Wave")
plt.plot(x,y_sin,'r')
plt.subplot(2,2,2)
plt.title("Cosine Wave") 
plt.plot(x,y_cos,'g')

# %%
x=[2,8,10]
y=[11,16,9]
x2=[3,9,11]
y2=[6,15,17]
plt.bar(x,y,color='r')
plt.bar(x2,y2,color='g')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Bar Plot')
plt.show()

# %%
x=np.array([22,11,47,52,12,60,8,27,42])
plt.hist(x)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Histogram')
plt.show()

# %%
data=[np.random.normal(0,std,100)for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=False)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Boxplot')
plt.show()

# %%
labels=['python','c++','Ruby','Java']
sizes=[215,130,245,210]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0.4,0,0,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x292f5408b00>,
# ...
#  [Text(0.9963786148748535, 1.1212625276089756, 'python'),
#   Text(-0.64656382751384, 0.8899186574910392, 'c++'),
#   Text(-0.94900779332915, -0.5562231640272972, 'Ruby'),
#   Text(0.7466808503372186, -0.8077547324155322, 'Java')])

# %%
df= sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dt=df[['total_bill','tip','size']]
dt.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
dt.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(dt.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x ='tip', y ='total_bill',data=dt, kind ='hex')

# %%
sns.pairplot(df,hue='sex')

# %%
sns.distplot(dt['tip'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10708\2393652879.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#rugplot
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
#rugplot
sns.rugplot(df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
#countplot
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#boxplot
sns.boxplot(x='sex', y='tip', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(dt)
# Out:
# <Axes: >

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
#box plot with hu
sns.boxplot(x='sex', y='tip', data=df, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# violin plot
sns.violinplot(x='total_bill', y='day', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# violin plot with hue
sns.violinplot(x='total_bill', y='day', data=df,hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
